# %% [markdown]
# # Storytelling project

# %%
import pandas as pd
import numpy as np
from pydataset import data
import matplotlib.pyplot as plt
import seaborn as sns

# %%
churndb = pd.read_csv('churn_data.csv')

# %%
churndb.head()
# Out:
#   customer_id clean_cust_id  gender  is_senior_citizen partner dependents  \
# 0  1371-DWPAZ    1371-DWPAZ  Female                  0     Yes        Yes
# 1  4472-LVYGI    4472-LVYGI  Female                  0     Yes        Yes
# 2  2520-SGTTA    2520-SGTTA  Female                  0     Yes        Yes
# 3  2923-ARZLG    2923-ARZLG    Male                  0     Yes        Yes
# 4  3115-CZMZD    3115-CZMZD    Male                  0      No        Yes
#
#    phone_service  internet_service  contract_type               payment_type  \
# 0              0                 1              2    Credit card (automatic)
# 1              0                 1              2  Bank transfer (automatic)
# 2              1                 0              2               Mailed check
# 3              1                 0              1               Mailed check
# 4              1                 0              2               Mailed check
#
#    ... has_phone_has_internet partner_dependents monthly_tenure_not_rounded  \
# 0  ...                  False                  3                        0.0
# 1  ...                  False                  3                        0.0
# 2  ...                  False                  3                        0.0
# 3  ...                  False                  3                        0.0
# 4  ...                  False                  2                        0.0
#
#    start_date  contract_description  phone_service_description  \
# 0   4/29/2021                2 Year           No Phone Service
# 1   4/29/2021                2 Year           No Phone Service
# 2   4/29/2021                2 Year                   One Line
# 3   4/29/2021                1 Year                   One Line
# 4   4/29/2021                2 Year                   One Line
#
#    internet_service_description  only_phone  only_internet   service_type
# 0                           DSL       False           True  Only Internet
# 1                           DSL       False           True  Only Internet
# 2           No Internet Service        True          False     Only Phone
# 3           No Internet Service        True          False     Only Phone
# 4           No Internet Service        True          False     Only Phone
#
# [5 rows x 28 columns]

# %%
churndb.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7043.000000    7043.000000       7043.000000    7043.000000
# mean            0.162147       1.325004          1.222916       0.690473
# std             0.368612       0.642730          0.778877       0.833755
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_tenure  partner_dependents  monthly_tenure_not_rounded
# count     7043.000000         7043.000000                 7043.000000
# mean        32.368309            1.082209                   32.373431
# std         24.597021            1.226274                   24.595943
# min          0.000000            0.000000                    0.000000
# 25%          9.000000            0.000000                    8.717230
# 50%         29.000000            1.000000                   28.673115
# 75%         55.000000            2.000000                   55.244460
# max         79.000000            3.000000                   79.341772

# %%
churndb.corr()
# Out:
#                             is_senior_citizen  phone_service  \
# is_senior_citizen                    1.000000       0.113791
# phone_service                        0.113791       1.000000
# internet_service                     0.259390       0.307988
# contract_type                       -0.142554       0.083343
# monthly_tenure                       0.016107       0.258792
# is_female                            0.001874       0.009451
# has_churned                          0.150889       0.036310
# has_phone                            0.008576       0.675070
# has_internet                         0.182742       0.082560
# has_phone_has_internet               0.167749       0.503650
# partner_dependents                  -0.151073       0.033120
# monthly_tenure_not_rounded           0.016185       0.258937
# only_phone                          -0.182742      -0.082560
# only_internet                       -0.008576      -0.675070
#
#                             internet_service  contract_type  monthly_tenure  \
# is_senior_citizen                   0.259390      -0.142554        0.016107
# phone_service                       0.307988       0.083343        0.258792
# internet_service                    1.000000      -0.290189        0.032938
# contract_type                      -0.290189       1.000000        0.671321
# monthly_tenure                      0.032938       0.671321        1.000000
# is_female                           0.010380      -0.000126       -0.004522
# has_churned                         0.316846      -0.396713       -0.351726
# has_phone                           0.093720       0.002247        0.008398
# has_internet                        0.825819      -0.242388        0.038591
# has_phone_has_internet              0.793101      -0.213817        0.039624
# partner_dependents                 -0.134267       0.301843        0.273160
# monthly_tenure_not_rounded          0.032832       0.671500        0.999940
# only_phone                         -0.825819       0.242388       -0.038591
# only_internet                      -0.093720      -0.002247       -0.008398
#
#                             is_female  has_churned  has_phone  has_internet  \
# is_senior_citizen            0.001874     0.150889   0.008576      0.182742
# phone_service                0.009451     0.036310   0.675070      0.082560
# internet_service             0.010380     0.316846   0.093720      0.825819
# contract_type               -0.000126    -0.396713   0.002247     -0.242388
# monthly_tenure              -0.004522    -0.351726   0.008398      0.038591
# is_female                    1.000000     0.008612   0.006488      0.006026
# has_churned                  0.008612     1.000000   0.011942      0.227890
# has_phone                    0.006488     0.011942   1.000000     -0.172209
# has_internet                 0.006026     0.227890  -0.172209      1.000000
# has_phone_has_internet       0.009487     0.209988   0.484538      0.778260
# partner_dependents          -0.007121    -0.184012   0.005899     -0.104712
# monthly_tenure_not_rounded  -0.004462    -0.351958   0.008528      0.038514
# only_phone                  -0.006026    -0.227890   0.172209     -1.000000
# only_internet               -0.006488    -0.011942  -1.000000      0.172209
#
#                             has_phone_has_internet  partner_dependents  \
# is_senior_citizen                         0.167749           -0.151073
# phone_service                             0.503650            0.033120
# internet_service                          0.793101           -0.134267
# contract_type                            -0.213817            0.301843
# monthly_tenure                            0.039624            0.273160
# is_female                                 0.009487           -0.007121
# has_churned                               0.209988           -0.184012
# has_phone                                 0.484538            0.005899
# has_internet                              0.778260           -0.104712
# has_phone_has_internet                    1.000000           -0.089228
# partner_dependents                       -0.089228            1.000000
# monthly_tenure_not_rounded                0.039638            0.273341
# only_phone                               -0.778260            0.104712
# only_internet                            -0.484538           -0.005899
#
#                             monthly_tenure_not_rounded  only_phone  \
# is_senior_citizen                             0.016185   -0.182742
# phone_service                                 0.258937   -0.082560
# internet_service                              0.032832   -0.825819
# contract_type                                 0.671500    0.242388
# monthly_tenure                                0.999940   -0.038591
# is_female                                    -0.004462   -0.006026
# has_churned                                  -0.351958   -0.227890
# has_phone                                     0.008528    0.172209
# has_internet                                  0.038514   -1.000000
# has_phone_has_internet                        0.039638   -0.778260
# partner_dependents                            0.273341    0.104712
# monthly_tenure_not_rounded                    1.000000   -0.038514
# only_phone                                   -0.038514    1.000000
# only_internet                                -0.008528   -0.172209
#
#                             only_internet
# is_senior_citizen               -0.008576
# phone_service                   -0.675070
# internet_service                -0.093720
# contract_type                   -0.002247
# monthly_tenure                  -0.008398
# is_female                       -0.006488
# has_churned                     -0.011942
# has_phone                       -1.000000
# has_internet                     0.172209
# has_phone_has_internet          -0.484538
# partner_dependents              -0.005899
# monthly_tenure_not_rounded      -0.008528
# only_phone                      -0.172209
# only_internet                    1.000000

# %%
sns.heatmap(churndb.corr(), cmap = 'RdBu')
# Out:
# <AxesSubplot:>

# %%
churndb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customer_id                   7043 non-null   object
#  1   clean_cust_id                 7043 non-null   object
#  2   gender                        7043 non-null   object
#  3   is_senior_citizen             7043 non-null   int64
#  4   partner                       7043 non-null   object
#  5   dependents                    7043 non-null   object
#  6   phone_service                 7043 non-null   int64
#  7   internet_service              7043 non-null   int64
#  8   contract_type                 7043 non-null   int64
#  9   payment_type                  7043 non-null   object
#  10  monthly_charges               7043 non-null   object
#  11  total_charges                 7043 non-null   object
#  12  churn                         7043 non-null   object
#  13  monthly_tenure                7043 non-null   int64
#  14  is_female                     7043 non-null   bool
#  15  has_churned                   7043 non-null   bool
#  16  has_phone                     7043 non-null   bool
#  17  has_internet                  7043 non-null   bool
#  18  has_phone_has_internet        7043 non-null   bool
#  19  partner_dependents            7043 non-null   int64
#  20  monthly_tenure_not_rounded    7043 non-null   float64
#  21  start_date                    7043 non-null   object
#  22  contract_description          7043 non-null   object
#  23  phone_service_description     7043 non-null   object
#  24  internet_service_description  7043 non-null   object
#  25  only_phone                    7043 non-null   bool
#  26  only_internet                 7043 non-null   bool
#  27  service_type                  7043 non-null   object
# dtypes: bool(7), float64(1), int64(6), object(14)
# memory usage: 1.2+ MB

# %%
#create variables that store the amount of customers who have churned or not
total_customers = churndb['has_churned'].count()
total_churned = churndb['has_churned'].value_counts()[1]
total_stayed = churndb['has_churned'].value_counts()[0]

# %%
churndb['contract_description'].value_counts()
# Out:
# Month-to-Month    3875
# 2 Year            1695
# 1 Year            1473
# Name: contract_description, dtype: int64

# %%
# percentage breakdown of contract type of customer base
# notice month to month is 55 percent
churndb['contract_description'].value_counts()/total_customers
# Out:
# Month-to-Month    0.550192
# 2 Year            0.240664
# 1 Year            0.209144
# Name: contract_description, dtype: float64

# %%
churndb.groupby(['has_churned', 'contract_description']).monthly_tenure.count()
# Out:
# has_churned  contract_description
# False        1 Year                  1307
#              2 Year                  1647
#              Month-to-Month          2220
# True         1 Year                   166
#              2 Year                    48
#              Month-to-Month          1655
# Name: monthly_tenure, dtype: int64

# %%
not_churned_contract_breakdown_s = churndb.groupby(['has_churned', 'contract_description']).monthly_tenure.count()[0]
not_churned_contract_breakdown_s
# Out:
# contract_description
# 1 Year            1307
# 2 Year            1647
# Month-to-Month    2220
# Name: monthly_tenure, dtype: int64

# %%
churned_contract_breakdown_s = churndb.groupby(['has_churned', 'contract_description']).monthly_tenure.count()[1]
churned_contract_breakdown_s
# Out:
# contract_description
# 1 Year             166
# 2 Year              48
# Month-to-Month    1655
# Name: monthly_tenure, dtype: int64

# %%
# percent of churnees with each contract type
# notice how large of a chunk these month to month customers are
churned_contract_breakdown_s/total_churned
# Out:
# contract_description
# 1 Year            0.088818
# 2 Year            0.025682
# Month-to-Month    0.885500
# Name: monthly_tenure, dtype: float64

# %%
# percent of non churnees with each contract type
# notice the portions are more spread out here
not_churned_contract_breakdown_s /total_stayed
# Out:
# contract_description
# 1 Year            0.252609
# 2 Year            0.318322
# Month-to-Month    0.429068
# Name: monthly_tenure, dtype: float64

# %%
churndb.monthly_tenure.value_counts().sort_index()
# Out:
# 0      11
# 1     617
# 2     232
# 3     204
# 4     171
# 5     147
# 6     102
# 7     127
# 8     120
# 9     130
# 10     95
# 11    125
# 12    107
# 13    111
# 14     88
# 15     77
# 16     90
# 17     97
# 18     84
# 19     69
# 20     56
# 21     98
# 22     83
# 23     84
# 24     86
# 25     80
# 26     76
# 27     70
# 28     75
# 29     64
# 30     69
# 31     72
# 32     58
# 33     77
# 34     71
# 35     63
# 36     66
# 37     56
# 38     66
# 39     51
# 40     59
# 41     66
# 42     62
# 43     66
# 44     61
# 45     58
# 46     76
# 47     66
# 48     65
# 49     64
# 50     66
# 51     76
# 52     80
# 53     63
# 54     82
# 55     67
# 56     58
# 57     73
# 58     56
# 59     68
# 60     90
# 61     73
# 62     58
# 63     85
# 64     89
# 65     71
# 66     87
# 67     90
# 68     99
# 69    102
# 70    153
# 71    174
# 72    144
# 73    106
# 74     41
# 75     15
# 76      3
# 77      5
# 79      1
# Name: monthly_tenure, dtype: int64

# %%
# Out:
# 0             2 Year
# 1             2 Year
# 2             2 Year
# 3             1 Year
# 4             2 Year
# 5             2 Year
# 6             2 Year
# 7             2 Year
# 8             2 Year
# 9             2 Year
# 10            2 Year
# 11    Month-to-Month
# 12    Month-to-Month
# 13    Month-to-Month
# 14    Month-to-Month
# 15    Month-to-Month
# 16            1 Year
# 17    Month-to-Month
# 18    Month-to-Month
# 19    Month-to-Month
# Name: contract_description, dtype: object

# %%
partner_counts_sorted = churndb.groupby(['has_churned', 'contract_description','partner_dependents']).partner_dependents.count()
partner_counts_sorted
# Out:
# has_churned  contract_description  partner_dependents
# False        1 Year                0                      497
#                                    1                      328
#                                    2                       78
#                                    3                      404
#              2 Year                0                      419
#                                    1                      456
#                                    2                       67
#                                    3                      705
#              Month-to-Month        0                     1241
#                                    1                      449
#                                    2                      139
#                                    3                      391
# True         1 Year                0                       61
#                                    1                       56
#                                    2                        7
#                                    3                       42
#              2 Year                0                       15
#                                    1                       15
#                                    2                        2
#                                    3                       16
#              Month-to-Month        0                     1047
#                                    1                      349
#                                    2                       68
#                                    3                      191
# Name: partner_dependents, dtype: int64

# %%
#dataframe that has all the customers who have churned
churneddf = churndb.where(churndb.has_churned == True)
churneddf = churneddf.dropna()

# %%
churneddf.groupby(['contract_description', 'partner_dependents']).partner_dependents.count()
# Out:
# contract_description  partner_dependents
# 1 Year                0.0                     61
#                       1.0                     56
#                       2.0                      7
#                       3.0                     42
# 2 Year                0.0                     15
#                       1.0                     15
#                       2.0                      2
#                       3.0                     16
# Month-to-Month        0.0                   1047
#                       1.0                    349
#                       2.0                     68
#                       3.0                    191
# Name: partner_dependents, dtype: int64

# %%
#dataframe that has all the month to month customers
mtmdf = churndb.where(churndb.contract_type == 0)
mtmdf = mtmdf.dropna()

# %%
#0	for no partners and no dependents
#1	indicates partner only
#2	indicates dependents only 
#3	indicates partner & dependents
# create data frame for the dependents key

familykey = [(0, 'no partner no dependents'),
            (1, 'partner only'),
            (2, 'dependents only'),
            (3, 'partner & dependents')]
familykeydf = pd.DataFrame(familykey, 
                          columns = ['fam_id', 'fam_description'])

# %%
familykeydf
# Out:
#    fam_id           fam_description
# 0       0  no partner no dependents
# 1       1              partner only
# 2       2           dependents only
# 3       3      partner & dependents

# %%
# merge with family key to get descriptions of family in dataframe
mtmdf = mtmdf.merge(familykeydf, left_on= 'partner_dependents', right_on = 'fam_id', how = 'right', indicator = False)
mtmdf.head()
# Out:
#   customer_id clean_cust_id  gender  is_senior_citizen partner dependents  \
# 0  1816-FLZDK    1816-FLZDK    Male                0.0      No         No
# 1  2049-BAFNW    2049-BAFNW  Female                0.0      No         No
# 2  2209-XADXF    2209-XADXF  Female                0.0      No         No
# 3  3439-GVUSX    3439-GVUSX    Male                0.0      No         No
# 4  4195-NZGTA    4195-NZGTA  Female                0.0      No         No
#
#    phone_service  internet_service  contract_type               payment_type  \
# 0            0.0               1.0            0.0               Mailed check
# 1            0.0               1.0            0.0               Mailed check
# 2            0.0               1.0            0.0  Bank transfer (automatic)
# 3            0.0               1.0            0.0               Mailed check
# 4            0.0               1.0            0.0           Electronic check
#
#    ... monthly_tenure_not_rounded start_date contract_description  \
# 0  ...                        1.0  3/29/2021       Month-to-Month
# 1  ...                        1.0  3/29/2021       Month-to-Month
# 2  ...                        1.0  3/29/2021       Month-to-Month
# 3  ...                        1.0  3/29/2021       Month-to-Month
# 4  ...                        1.0  3/29/2021       Month-to-Month
#
#    phone_service_description  internet_service_description  only_phone  \
# 0           No Phone Service                           DSL         0.0
# 1           No Phone Service                           DSL         0.0
# 2           No Phone Service                           DSL         0.0
# 3           No Phone Service                           DSL         0.0
# 4           No Phone Service                           DSL         0.0
#
#    only_internet   service_type  fam_id           fam_description
# 0            1.0  Only Internet       0  no partner no dependents
# 1            1.0  Only Internet       0  no partner no dependents
# 2            1.0  Only Internet       0  no partner no dependents
# 3            1.0  Only Internet       0  no partner no dependents
# 4            1.0  Only Internet       0  no partner no dependents
#
# [5 rows x 30 columns]

# %%
#do the same with the churned df
churneddf = churneddf.merge(familykeydf, left_on= 'partner_dependents', right_on = 'fam_id', how = 'right', indicator = False)
churneddf.head()
# Out:
#   customer_id clean_cust_id  gender  is_senior_citizen partner dependents  \
# 0  0023-HGHWL    0023-HGHWL    Male                1.0      No         No
# 1  0375-HVGXO    0375-HVGXO  Female                0.0      No         No
# 2  0612-RTZZA    0612-RTZZA  Female                1.0      No         No
# 3  0661-XEYAN    0661-XEYAN  Female                1.0      No         No
# 4  0841-NULXI    0841-NULXI    Male                0.0      No         No
#
#    phone_service  internet_service  contract_type      payment_type  ...  \
# 0            0.0               1.0            0.0  Electronic check  ...
# 1            0.0               1.0            0.0  Electronic check  ...
# 2            0.0               1.0            0.0  Electronic check  ...
# 3            0.0               1.0            0.0      Mailed check  ...
# 4            0.0               1.0            0.0  Electronic check  ...
#
#   monthly_tenure_not_rounded start_date contract_description  \
# 0                        1.0  3/29/2021       Month-to-Month
# 1                        1.0  3/29/2021       Month-to-Month
# 2                        1.0  3/29/2021       Month-to-Month
# 3                        1.0  3/29/2021       Month-to-Month
# 4                        1.0  3/29/2021       Month-to-Month
#
#    phone_service_description  internet_service_description  only_phone  \
# 0           No Phone Service                           DSL         0.0
# 1           No Phone Service                           DSL         0.0
# 2           No Phone Service                           DSL         0.0
# 3           No Phone Service                           DSL         0.0
# 4           No Phone Service                           DSL         0.0
#
#    only_internet   service_type  fam_id           fam_description
# 0            1.0  Only Internet       0  no partner no dependents
# 1            1.0  Only Internet       0  no partner no dependents
# 2            1.0  Only Internet       0  no partner no dependents
# 3            1.0  Only Internet       0  no partner no dependents
# 4            1.0  Only Internet       0  no partner no dependents
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Now have two dataframes churneddf (all the info for people who churned), and mtmdf (all the info for people who are month to month)

# %%
churneddf.groupby(['contract_description', 'fam_description']).fam_description.count()
# Out:
# contract_description  fam_description
# 1 Year                dependents only                7
#                       no partner no dependents      61
#                       partner & dependents          42
#                       partner only                  56
# 2 Year                dependents only                2
#                       no partner no dependents      15
#                       partner & dependents          16
#                       partner only                  15
# Month-to-Month        dependents only               68
#                       no partner no dependents    1047
#                       partner & dependents         191
#                       partner only                 349
# Name: fam_description, dtype: int64

# %%
mtmdf.groupby(['has_churned', 'fam_description']).fam_description.count()
# Out:
# has_churned  fam_description
# 0.0          dependents only              139
#              no partner no dependents    1241
#              partner & dependents         391
#              partner only                 449
# 1.0          dependents only               68
#              no partner no dependents    1047
#              partner & dependents         191
#              partner only                 349
# Name: fam_description, dtype: int64

# %%
#string money float the monthly_charges column
mtmdf['monthly_charges'] = mtmdf['monthly_charges'].str.replace('$', '').astype(float)

# %%
churneddf['monthly_charges'] = churneddf['monthly_charges'].str.replace('$', '').astype(float)

# %%
churndb['monthly_charges'] = churndb['monthly_charges'].str.replace('$', '').astype(float)

# %%
mtmdf.groupby('has_churned').monthly_charges.agg('mean')
# Out:
# has_churned
# 0.0    61.462635
# 1.0    73.019396
# Name: monthly_charges, dtype: float64

# %% [markdown]
# People on month to month who churn are paying more per month
# - customers who churned pay on average 18.81 percent higher on their monthly bill
# - that's 11.56 more per month
# - that's also above the entire population average which is 64.76
#
# To calculate percent higher
# - ((N2-N1)/N1)*100 = PH
# - ((73.02-61.46)/61.46)*100=18.81%

# %%
mtmdf.groupby(['has_churned', 'service_type']).service_type.count()
# Out:
# has_churned  service_type
# 0.0          Only Internet        223
#              Only Phone           425
#              Phone & Internet    1572
# 1.0          Only Internet        153
#              Only Phone            99
#              Phone & Internet    1403
# Name: service_type, dtype: int64

# %%
mtmdf.monthly_charges.agg('mean')
# Out:
# 66.39849032258051

# %%
# Out:
#      customer_id clean_cust_id  gender  is_senior_citizen partner dependents  \
# 0     1371-DWPAZ    1371-DWPAZ  Female                  0     Yes        Yes
# 1     4472-LVYGI    4472-LVYGI  Female                  0     Yes        Yes
# 2     2520-SGTTA    2520-SGTTA  Female                  0     Yes        Yes
# 3     2923-ARZLG    2923-ARZLG    Male                  0     Yes        Yes
# 4     3115-CZMZD    3115-CZMZD    Male                  0      No        Yes
# ...          ...           ...     ...                ...     ...        ...
# 7038  3259-FDWOY    3259-FDWOY    Male                  0     Yes        Yes
# 7039  3512-IZIKN    3512-IZIKN  Female                  0     Yes         No
# 7040  0917-EZOLA    0917-EZOLA    Male                  1     Yes         No
# 7041  2889-FPWRM    2889-FPWRM    Male                  0     Yes         No
# 7042  3886-CERTZ    3886-CERTZ  Female                  0     Yes         No
#
#       phone_service  internet_service  contract_type  \
# 0                 0                 1              2
# 1                 0                 1              2
# 2                 1                 0              2
# 3                 1                 0              1
# 4                 1                 0              2
# ...             ...               ...            ...
# 7038              2                 2              2
# 7039              2                 1              2
# 7040              2                 2              2
# 7041              2                 2              1
# 7042              2                 2              1
#
#                    payment_type  ... has_phone_has_internet  \
# 0       Credit card (automatic)  ...                  False
# 1     Bank transfer (automatic)  ...                  False
# 2                  Mailed check  ...                  False
# 3                  Mailed check  ...                  False
# 4                  Mailed check  ...                  False
# ...                         ...  ...                    ...
# 7038  Bank transfer (automatic)  ...                   True
# 7039    Credit card (automatic)  ...                   True
# 7040  Bank transfer (automatic)  ...                   True
# 7041  Bank transfer (automatic)  ...                   True
# 7042           Electronic check  ...                   True
#
#      partner_dependents monthly_tenure_not_rounded  start_date  \
# 0                     3                   0.000000   4/29/2021
# 1                     3                   0.000000   4/29/2021
# 2                     3                   0.000000   4/29/2021
# 3                     3                   0.000000   4/29/2021
# 4                     2                   0.000000   4/29/2021
# ...                 ...                        ...         ...
# 7038                  3                  72.865094    4/4/2015
# 7039                  1                  72.890505    4/3/2015
# 7040                  1                  73.835334    3/6/2015
# 7041                  1                  73.724958    3/9/2015
# 7042                  1                  74.231579   2/22/2015
#
#       contract_description  phone_service_description  \
# 0                   2 Year           No Phone Service
# 1                   2 Year           No Phone Service
# 2                   2 Year                   One Line
# 3                   1 Year                   One Line
# 4                   2 Year                   One Line
# ...                    ...                        ...
# 7038                2 Year          Two or More Lines
# 7039                2 Year          Two or More Lines
# 7040                2 Year          Two or More Lines
# 7041                1 Year          Two or More Lines
# 7042                1 Year          Two or More Lines
#
#       internet_service_description  only_phone  only_internet  \
# 0                              DSL       False           True
# 1                              DSL       False           True
# 2              No Internet Service        True          False
# 3              No Internet Service        True          False
# 4              No Internet Service        True          False
# ...                            ...         ...            ...
# 7038                   Fiber Optic       False          False
# 7039                           DSL       False          False
# 7040                   Fiber Optic       False          False
# 7041                   Fiber Optic       False          False
# 7042                   Fiber Optic       False          False
#
#           service_type
# 0        Only Internet
# 1        Only Internet
# 2           Only Phone
# 3           Only Phone
# 4           Only Phone
# ...                ...
# 7038  Phone & Internet
# 7039  Phone & Internet
# 7040  Phone & Internet
# 7041  Phone & Internet
# 7042  Phone & Internet
#
# [7043 rows x 28 columns]

# %%
# group by two aggragates 
# see count and monthly average
churneddf.groupby('service_type').agg({'service_type' : 'count', 'monthly_charges' : 'mean'})
# Out:
#                   service_type  monthly_charges
# service_type
# Only Internet              170        37.533824
# Only Phone                 113        20.368142
# Phone & Internet          1586        82.250000

# %% [markdown]
# Obviously phone and internet is more expensive on average, however that's also the bulk of the people who are customers with the company

# %%
# break down averages per service type
# notice month to month customers who did not churn pay on average a lower cost for phone & internet. the bulk of our customers
mtmdf.groupby(['has_churned', 'service_type']).agg({'service_type' : 'count', 'monthly_charges' : 'mean'})
# Out:
#                               service_type  monthly_charges
# has_churned service_type
# 0.0         Only Internet              223        37.070852
#             Only Phone                 425        20.462941
#             Phone & Internet          1572        76.007316
# 1.0         Only Internet              153        36.456536
#             Only Phone                  99        20.180303
#             Phone & Internet          1403        80.735139

# %%
churndb.groupby('service_type').agg({'service_type' : 'count', 'monthly_charges' : 'mean'})
# Out:
#                   service_type  monthly_charges
# service_type
# Only Internet              682        42.028592
# Only Phone                1526        21.079194
# Phone & Internet          4835        81.755171

# %%
# find tenure month where churn is highest
churned_tenure_df = churneddf['monthly_tenure'].value_counts().sort_index()

# %%
churned_tenure_df.plot()
# Out:
# <AxesSubplot:>

# %%
churned_tenure_df = pd.DataFrame(churned_tenure_df)

# %%
churned_tenure_df = churned_tenure_df.reset_index()

# %%
churned_tenure_df = churned_tenure_df.rename(columns = {'index': 'months_with_company', 'monthly_tenure': 'num_customers'})

# %%
sns.lineplot(data = churned_tenure_df)
# Out:
# <AxesSubplot:>
